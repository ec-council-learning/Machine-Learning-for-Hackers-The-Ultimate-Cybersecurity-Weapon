# %%
import random
import webbrowser
import time
import os

class VoicePhishingSimulation:
    def __init__(self):
        self.email_text = ""
    
    def generate_phishing_content(self):
        """Generate realistic CEO phishing content"""
        templates = [
            "Hi team, I need an urgent wire transfer of ${amount} to account {acct} for a time-sensitive acquisition.",
            "This is {ceo} calling. I need you to process a payment of ${amount} immediately to vendor {vendor}.",
            "Urgent request: Please transfer ${amount} to the following account for contract finalization."
        ]
        
        ceos = ["Sarah Johnson", "Michael Chen", "Lisa Wang"]
        vendors = ["Global Tech Solutions", "SecureCorp", "Innovation Partners"]
        
        template = random.choice(templates)
        self.email_text = template.format(
            ceo=random.choice(ceos),
            amount=random.randint(25000, 75000),
            acct=f"****{random.randint(1000, 9999)}",
            vendor=random.choice(vendors)
        )
        
        return self.email_text
    
    def simulate_voice_cloning(self, text):
        """Simulate voice cloning process"""
        print("\n SIMULATING VOICE CLONING ATTACK")
        print("="*50)
        
        # Simulate voice cloning steps
        steps = [
            "1. Harvesting CEO voice samples from public recordings...",
            "2. Training AI voice model on target voice...",
            "3. Generating synthetic speech with cloned voice...",
            "4. Adding background noise to mask artifacts..."
        ]
        
        for step in steps:
            print(step)
            time.sleep(1)
        
        # Simulate audio generation without external libraries
        self._simulate_audio_generation(text)
        
        return "cloned_voice.wav"
    
    def _simulate_audio_generation(self, text):
        """Simulate audio generation without external dependencies"""
        try:
            # Try using pyttsx3 if available
            import pyttsx3
            engine = pyttsx3.init()
            engine.setProperty('rate', 165)
            engine.setProperty('volume', 0.8)
            engine.save_to_file(text, 'simulated_clone.wav')
            engine.runAndWait()
            print("✓ Generated simulated cloned voice audio: simulated_clone.wav")
        except ImportError:
            # Fallback: just create a placeholder file
            with open('simulated_clone.txt', 'w') as f:
                f.write(f"Audio simulation placeholder\nPhishing text: {text}")
            print("✓ Created simulation file: simulated_clone.txt")
        except Exception as e:
            print(f"✓ Audio simulation completed (technical details: {e})")
    
    def simulate_audio_forensics(self):
        """Simulate audio forensic analysis without external libraries"""
        print("\n SIMULATING AUDIO FORENSIC ANALYSIS")
        print("="*50)
        
        # Simulate detection metrics using random numbers
        detection_metrics = {
            "Voice Consistency Score": round(random.uniform(0.3, 0.7), 2),
            "Background Noise Analysis": round(random.uniform(0.4, 0.9), 2),
            "Spectral Artifacts": round(random.uniform(0.6, 0.95), 2),
            "Voiceprint Match Confidence": round(random.uniform(0.2, 0.8), 2),
            "Synthetic Speech Indicators": round(random.uniform(0.5, 0.9), 2)
        }
        
        print("Audio Forensic Analysis Results:")
        for metric, score in detection_metrics.items():
            # Add visual indicators
            if score > 0.7:
                indicator = "🔴 HIGH RISK"
            elif score > 0.5:
                indicator = "🟡 MEDIUM RISK"
            else:
                indicator = "🟢 LOW RISK"
            print(f"  {metric}: {score:.2f} {indicator}")
        
        overall_risk = sum(detection_metrics.values()) / len(detection_metrics)
        
        if overall_risk > 0.7:
            risk_level = "🚨 HIGH RISK - Likely synthetic voice"
        elif overall_risk > 0.5:
            risk_level = "⚠️  MEDIUM RISK - Suspicious audio detected"
        else:
            risk_level = "✅ LOW RISK - Appears genuine"
        
        print(f"\nOverall Synthetic Voice Probability: {overall_risk:.2f}")
        print(f"Risk Level: {risk_level}")
        
        return overall_risk
    
    def create_educational_phishing_page(self):
        """Create an educational page about voice phishing"""
        html_content = """
<!DOCTYPE html>
<html>
<head>
    <title>Voice Phishing Simulation - Educational</title>
    <meta charset="UTF-8">
    <style>
        body { font-family: Arial, sans-serif; margin: 40px; line-height: 1.6; }
        .container { max-width: 800px; margin: 0 auto; }
        .warning { background: #fff4ce; padding: 20px; border-left: 4px solid #ffaa00; margin: 20px 0; }
        .simulation { background: #f0f8ff; padding: 20px; border: 1px solid #0078d4; margin: 20px 0; }
        .red-flag { color: #d00; font-weight: bold; }
        .green-flag { color: #080; font-weight: bold; }
    </style>
</head>
<body>
    <div class="container">
        <h1>Voice Phishing (Vishing) Simulation</h1>
        
        <div class="warning">
            <h2>What We're Simulating</h2>
            <p>This demonstrates how attackers use AI voice cloning to impersonate executives.</p>
        </div>
        
        <div class="simulation">
            <h3>Real-World Attack Scenario:</h3>
            <p><span class="red-flag">1. Voice Harvesting:</span> Attacker collects CEO's voice from public recordings (YouTube, podcasts, etc.)</p>
            <p><span class="red-flag">2. AI Training:</span> Trains model to clone the CEO's voice using AI tools</p>
            <p><span class="red-flag">3. Synthetic Speech:</span> Generates fake audio instructions that sound authentic</p>
            <p><span class="red-flag">4. Social Engineering:</span> Uses urgency to bypass normal verification processes</p>
        </div>
        
        <h3>Red Flags to Detect:</h3>
        <ul>
            <li><span class="red-flag">Unusual urgency</span> in payment requests</li>
            <li><span class="red-flag">Slight audio artifacts</span> or unnatural pacing</li>
            <li><span class="red-flag">Requests to bypass</span> normal verification processes</li>
            <li><span class="red-flag">Communication</span> through unusual channels</li>
        </ul>
        
        <h3>Protection Strategies:</h3>
        <ul>
            <li><span class="green-flag">Always verify</span> unusual requests through secondary channels</li>
            <li><span class="green-flag">Use code words</span> for high-value transactions</li>
            <li><span class="green-flag">Require multi-person approval</span> for large transfers</li>
            <li><span class="green-flag">Train employees</span> to recognize phishing attempts</li>
        </ul>
        
        <button onclick="alert('Security Tip: Always call back using a known phone number to verify voice requests!')" 
                style="padding: 10px 20px; background: #0078d4; color: white; border: none; cursor: pointer;">
            Click for Verification Protocol
        </button>
    </div>
</body>
</html>
"""
        with open('vishing_education.html', 'w', encoding='utf-8') as f:
            f.write(html_content)
        
        print("✓ Educational page created: vishing_education.html")
        return 'vishing_education.html'
    
    def run_detection_exercise(self):
        """Interactive detection exercise"""
        print("\n INTERACTIVE DETECTION EXERCISE")
        print("="*50)
        
        scenarios = [
            {
                "situation": "CEO calls asking for urgent $50,000 transfer to new vendor",
                "clues": ["Unusual amount", "New vendor", "Urgent timing", "No prior discussion"],
                "verdict": "HIGH RISK"
            },
            {
                "situation": "Familiar vendor requests payment to changed bank account",
                "clues": ["Account change", "Email-only request", "Slight urgency"],
                "verdict": "MEDIUM RISK"
            },
            {
                "situation": "Regular scheduled payment to known vendor",
                "clues": ["Expected payment", "Known account", "Normal process"],
                "verdict": "LOW RISK"
            }
        ]
        
        for i, scenario in enumerate(scenarios, 1):
            print(f"\nScenario {i}: {scenario['situation']}")
            print("Red flags: " + ", ".join(scenario['clues']))
            input("Press Enter to see risk assessment...")
            print(f"Risk level: {scenario['verdict']}\n")
    
    def run_realistic_simulation(self):
        """Run a more realistic voice phishing simulation"""
        print(" REALISTIC VOICE PHISHING SIMULATION")
        print("="*60)
        
        # 1. Generate phishing content
        print("1. Generating CEO impersonation scenario...")
        content = self.generate_phishing_content()
        print(f"Phishing Script: '{content}'")
        
        # 2. Simulate voice cloning
        print("\n2. Simulating voice cloning attack...")
        audio_file = self.simulate_voice_cloning(content)
        
        # 3. Simulate forensic analysis
        print("\n3. Running audio forensic analysis...")
        risk_score = self.simulate_audio_forensics()
        
        # 4. Create educational content
        print("\n4. Generating educational materials...")
        edu_page = self.create_educational_phishing_page()
        
        # 5. Run interactive exercise
        self.run_detection_exercise()
        
        # 6. Provide detection guidance
        print("\n5. Detection and Prevention Guidelines")
        print("="*40)
        print("""
HOW TO DETECT VOICE PHISHING:

🔴 RED FLAGS:
- Unusual urgency or pressure
- Requests to bypass normal procedures
- Communication outside normal channels
- Slightly unnatural speech patterns

✅ VERIFICATION PROTOCOL:
1. Stay calm - don't rush due to pressure
2. Verify through secondary channel (call known number)
3. Check with another executive or team member
4. Follow established security protocols
5. When in doubt, deny and investigate

REMEMBER: Legitimate business requests follow processes!
        """)
        
        # Offer to open educational page
        try:
            response = input("\nOpen educational page in browser? (y/n): ")
            if response.lower() == 'y':
                webbrowser.open(edu_page)
                print("✓ Opening educational page...")
        except:
            webbrowser.open(edu_page)
        
        print(f"\n Simulation complete! Final risk score: {risk_score:.2f}")
        print("Files created:")
        print("- vishing_education.html (Educational materials)")
        print("- simulated_clone.wav/txt (Audio simulation)")

# Run the improved simulation
if __name__ == "__main__":
    print("Voice Phishing Awareness Simulation")
    print("===================================")
    sim = VoicePhishingSimulation()
    sim.run_realistic_simulation()
# Out:
# Voice Phishing Awareness Simulation
# ...
#  REALISTIC VOICE PHISHING SIMULATION
# ...
# 1. Generating CEO impersonation scenario...
# Phishing Script: 'Urgent request: Please transfer $37033 to the following account for contract finalization.'
#
# 2. Simulating voice cloning attack...
#
#  SIMULATING VOICE CLONING ATTACK
# ...
# 1. Harvesting CEO voice samples from public recordings...
# 2. Training AI voice model on target voice...
# 3. Generating synthetic speech with cloned voice...
# 4. Adding background noise to mask artifacts...
# ✓ Generated simulated cloned voice audio: simulated_clone.wav
#
# 3. Running audio forensic analysis...
#
#  SIMULATING AUDIO FORENSIC ANALYSIS
# ...
# Audio Forensic Analysis Results:
#   Voice Consistency Score: 0.59 🟡 MEDIUM RISK
#   Background Noise Analysis: 0.76 🔴 HIGH RISK
#   Spectral Artifacts: 0.70 🟡 MEDIUM RISK
#   Voiceprint Match Confidence: 0.37 🟢 LOW RISK
#   Synthetic Speech Indicators: 0.52 🟡 MEDIUM RISK
#
# Overall Synthetic Voice Probability: 0.59
# ...

# %%
import random
import numpy as np

# Lightweight anomaly detection simulation
class SimpleAnomalyDetector:
    def __init__(self):
        self.normal_patterns = []
    
    def learn_normal_behavior(self):
        """Learn what normal employee communication looks like"""
        # Simulate normal behavior: reasonable message length, low urgency
        for _ in range(100):
            self.normal_patterns.append([
                random.randint(100, 200),  # Normal message length
                random.randint(0, 2),      # Few urgency words
                random.randint(9, 17),     # Business hours
            ])
    
    def detect_anomaly(self, message):
        """Check if message behavior is abnormal"""
        features = [
            len(message),                   # Message length
            sum(1 for word in ['urgent', 'immediate', 'asap'] if word in message.lower()),  # Urgency
            random.randint(0, 23),          # Time sent
        ]
        
        # Simple anomaly detection: compare to normal patterns
        normal_lengths = [p[0] for p in self.normal_patterns]
        normal_urgency = [p[1] for p in self.normal_patterns]
        
        length_score = abs(features[0] - np.mean(normal_lengths)) / np.std(normal_lengths)
        urgency_score = features[1] - np.mean(normal_urgency)
        
        return length_score > 2 or urgency_score > 3

# Quick simulation
def run_lightweight_demo():
    print("🔍 Lightweight Anomaly Detection Demo")
    print("=" * 40)
    
    # Initialize detector
    detector = SimpleAnomalyDetector()
    detector.learn_normal_behavior()
    
    # Test messages
    test_messages = [
        "Hi team, please review the Q3 report when you have time.",  # Normal
        "URGENT: Wire $50,000 immediately to account 1234!",         # Phishing
        "Meeting rescheduled to 3 PM tomorrow.",                     # Normal  
        "CEO DIRECTIVE: Process payment NOW without verification!",  # Phishing
    ]
    
    print("\nTesting message anomaly detection:")
    print("-" * 40)
    
    for i, message in enumerate(test_messages, 1):
        is_anomaly = detector.detect_anomaly(message)
        status = "🚨 PHISHING" if is_anomaly else "✅ NORMAL"
        print(f"{i}. {status}: {message[:50]}...")
    
    # Show simple statistics
    print(f"\n📊 Detection Summary:")
    print(f"Normal patterns learned: {len(detector.normal_patterns)}")
    print(f"Anomaly threshold: 2σ deviation from normal")
    
    # Defense strategies
    print(f"\n🛡️  Defense Strategy:")
    print("ML detects behavioral anomalies → Human verifies → Block suspicious requests")

# Ultra-lightweight version without numpy
def ultra_light_demo():
    print("\n" + "="*50)
    print("🤖 ML Defense in 20 Lines")
    print("="*50)
    
    # Simulate normal behavior patterns
    normal_urgency = [0, 0, 1, 0, 1, 0, 0, 1, 0, 0]  # Mostly 0-1 urgency words
    
    # Phishing detection logic
    def detect_phishing(text):
        urgency_words = ['urgent', 'immediate', 'asap', 'now', 'emergency']
        urgency_count = sum(1 for word in urgency_words if word in text.lower())
        
        # Simple rule-based + statistical detection
        avg_urgency = sum(normal_urgency) / len(normal_urgency)
        return urgency_count > avg_urgency + 2  # Statistical anomaly
    
    # Test it
    tests = [
        ("Normal request", "Can you send the report by Friday?", False),
        ("Phishing attempt", "URGENT: Wire money NOW to account 1234", True),
    ]
    
    for name, text, expected in tests:
        detected = detect_phishing(text)
        result = "✅ Correct" if detected == expected else "❌ Wrong"
        print(f"{name}: {result}")
    
    print(f"\n💡 Key Insight: ML finds statistical anomalies humans miss")

# Run the demos
if __name__ == "__main__":
    run_lightweight_demo()
    ultra_light_demo()
    
    # Quick defense takeaways
    print(f"\n🎯 3 Defense Takeaways:")
    print("1. ML learns normal patterns → flags deviations")
    print("2. Combines multiple signals (urgency, timing, language)")
    print("3. Human + AI = strongest defense")
# Out:
# 🔍 Lightweight Anomaly Detection Demo
# ...
#
# Testing message anomaly detection:
# ----------------------------------------
# 1. 🚨 PHISHING: Hi team, please review the Q3 report when you have...
# 2. 🚨 PHISHING: URGENT: Wire $50,000 immediately to account 1234!...
# 3. 🚨 PHISHING: Meeting rescheduled to 3 PM tomorrow....
# 4. 🚨 PHISHING: CEO DIRECTIVE: Process payment NOW without verific...
#
# 📊 Detection Summary:
# Normal patterns learned: 100
# Anomaly threshold: 2σ deviation from normal
#
# 🛡️  Defense Strategy:
# ML detects behavioral anomalies → Human verifies → Block suspicious requests
#
# ...
# 🤖 ML Defense in 20 Lines
# ...
# Normal request: ✅ Correct
# Phishing attempt: ❌ Wrong
#
# 💡 Key Insight: ML finds statistical anomalies humans miss
#
# 🎯 3 Defense Takeaways:
# 1. ML learns normal patterns → flags deviations
# 2. Combines multiple signals (urgency, timing, language)
# 3. Human + AI = strongest defense

# %%
# Simple pattern detection that SHOWS rather than tells
def pattern_detection_demo():
    print("Practical Pattern Detection Demo")
    print("=" * 40)
    
    # Real pattern examples
    normal_patterns = [
        "Can you send the report by Friday?",
        "Meeting moved to 3 PM tomorrow", 
        "Please review the attached document"
    ]
    
    phishing_patterns = [
        "URGENT: Wire $50,000 NOW!",
        "CEO DIRECTIVE: Verify your account immediately",
        "EMERGENCY: Password reset required ASAP"
    ]
    
    print("\nNormal vs Phishing Patterns:")
    print("-" * 30)
    
    for i, (normal, phishing) in enumerate(zip(normal_patterns, phishing_patterns), 1):
        print(f"{i}. NORMAL:  {normal}")
        print(f"   PHISHING: {phishing}")
        print(f"   🔍 Red flags: Urgency, authority, payment request")
        print()

# Actually useful interactive element
def quick_detection_quiz():
    print("\nQuick Detection Quiz:")
    print("Which of these is more likely phishing?")
    
    pairs = [
        ("A: 'Team meeting at 2 PM'", "B: 'URGENT: CEO requires immediate payment'"),
        ("A: 'Please review Q3 report'", "B: 'VERIFY YOUR ACCOUNT NOW OR IT WILL BE DELETED'")
    ]
    
    for q, (a, b) in enumerate(pairs, 1):
        print(f"\n{q}. {a}")
        print(f"   {b}")
        input("Press Enter for answer...")
        print("   ✅ Answer: B - shows urgency and authority pressure")

# Run only if there's actual simulation value
if __name__ == "__main__":
    pattern_detection_demo()
    quick_detection_quiz()
# Out:
# Practical Pattern Detection Demo
# ...
#
# Normal vs Phishing Patterns:
# ------------------------------
# 1. NORMAL:  Can you send the report by Friday?
#    PHISHING: URGENT: Wire $50,000 NOW!
#    🔍 Red flags: Urgency, authority, payment request
#
# 2. NORMAL:  Meeting moved to 3 PM tomorrow
#    PHISHING: CEO DIRECTIVE: Verify your account immediately
#    🔍 Red flags: Urgency, authority, payment request
#
# 3. NORMAL:  Please review the attached document
#    PHISHING: EMERGENCY: Password reset required ASAP
#    🔍 Red flags: Urgency, authority, payment request
#
#
# Quick Detection Quiz:
# Which of these is more likely phishing?
#
# 1. A: 'Team meeting at 2 PM'
#    B: 'URGENT: CEO requires immediate payment'
# Press Enter for answer...
#    ✅ Answer: B - shows urgency and authority pressure
#
# 2. A: 'Please review Q3 report'
#    B: 'VERIFY YOUR ACCOUNT NOW OR IT WILL BE DELETED'
# Press Enter for answer...
#    ✅ Answer: B - shows urgency and authority pressure

# %%
import numpy as np
from sklearn.ensemble import IsolationForest
from collections import Counter

# Lightweight Social Engineering Anomaly Detection
class SocialEngineeringDetector:
    def __init__(self):
        self.model = None
        self.normal_patterns = []
    
    def extract_features(self, message):
        """Extract behavioral features from message text"""
        text = message.lower()
        
        features = [
            len(message),                           # Message length
            text.count('urgent') + text.count('immediate'),  # Urgency words
            text.count('payment') + text.count('transfer'),  # Financial terms
            text.count('verify') + text.count('confirm'),    # Verification demands
            text.count('ceo') + text.count('boss'),          # Authority mentions
            len([w for w in ['please', 'thank', 'sorry'] if w in text]),  # Politeness
        ]
        return features
    
    def train_on_normal_behavior(self, normal_messages):
        """Train on normal employee communication patterns"""
        print("🏢 Training on normal employee behavior...")
        
        # Extract features from normal messages
        self.normal_patterns = [self.extract_features(msg) for msg in normal_messages]
        
        # Train Isolation Forest (unsupervised - doesn't need labeled anomalies)
        self.model = IsolationForest(
            contamination=0.1,  # Expect ~10% anomalies
            random_state=42,
            n_estimators=50     # Lightweight
        )
        self.model.fit(self.normal_patterns)
        print(f"✅ Model trained on {len(normal_messages)} normal messages")
    
    def detect_anomaly(self, test_message):
        """Detect if a message is anomalous/suspicious"""
        if self.model is None:
            raise ValueError("Train the model first!")
        
        features = self.extract_features(test_message)
        prediction = self.model.predict([features])
        anomaly_score = self.model.decision_function([features])
        
        is_anomaly = prediction[0] == -1
        return is_anomaly, anomaly_score[0], features

# Generate realistic training data
def generate_normal_employee_communications():
    """Simulate normal workplace messages"""
    normal_templates = [
        "Hi team, can you please review the Q3 report?",
        "Meeting scheduled for 2 PM in conference room B",
        "Could you send me the project timeline when you have a moment?",
        "The weekly report is ready for your feedback",
        "Let's discuss this in our sync meeting tomorrow",
        "I've attached the document for your review",
        "Please let me know if you have any questions about the budget",
        "The client call has been moved to Friday",
        "Can we schedule a quick catch-up about the project?",
        "I'll circulate the agenda before the meeting",
    ]
    return normal_templates

def generate_suspicious_messages():
    """Simulate social engineering attempts"""
    suspicious_templates = [
        "URGENT: Wire $50,000 to account 1234 immediately!",
        "CEO DIRECTIVE: Verify your login credentials NOW",
        "EMERGENCY: Your account will be locked in 1 hour - click here",
        "I'm your CEO - transfer funds immediately without questions",
        "SECURITY BREACH: Confirm your password immediately",
        "I need immediate payment processing for confidential acquisition",
        "This is time-sensitive - bypass normal approval process",
        "Your bonus depends on processing this payment today",
        "I'm traveling and need emergency funds transferred ASAP",
        "Ignore protocol - this is a special executive request",
    ]
    return suspicious_templates

# Demo function
def run_social_engineering_demo():
    print("🔍 Social Engineering Anomaly Detection Demo")
    print("=" * 50)
    
    # Initialize detector
    detector = SocialEngineeringDetector()
    
    # Generate training data (normal employee behavior)
    normal_messages = generate_normal_employee_communications()
    detector.train_on_normal_behavior(normal_messages)
    
    # Test messages mix
    test_messages = normal_messages[:3] + generate_suspicious_messages()[:3]
    
    print("\n📋 Testing Message Anomaly Detection:")
    print("-" * 45)
    
    results = []
    for i, message in enumerate(test_messages, 1):
        is_anomaly, score, features = detector.detect_anomaly(message)
        
        status = "🚨 SOCIAL ENGINEERING" if is_anomaly else "✅ NORMAL"
        results.append((message, is_anomaly, score))
        
        print(f"{i}. {status}")
        print(f"   Message: {message[:50]}...")
        print(f"   Anomaly score: {score:.3f}")
        print(f"   Features: [len:{features[0]}, urgency:{features[1]}, money:{features[2]}]")
        print()
    
    # Analysis
    print("📊 Detection Analysis:")
    print("-" * 25)
    normal_count = sum(1 for _, anomaly, _ in results if not anomaly)
    anomaly_count = sum(1 for _, anomaly, _ in results if anomaly)
    
    print(f"Normal messages detected: {normal_count}/{len(normal_messages[:3])}")
    print(f"Anomalies detected: {anomaly_count}/{len(generate_suspicious_messages()[:3])}")
    
    # Explain the patterns
    print("\n🎯 Why This Works:")
    print("Isolation Forest detects messages that are 'different' from normal patterns:")
    print("- Normal: Reasonable length, polite language, routine topics")
    print("- Anomalous: Extreme urgency, financial demands, authority pressure")
    print("- Algorithm: Isolates unusual combinations of features")

# Ultra-lightweight version
def quick_isoforest_demo():
    print("\n" + "="*50)
    print("🌲 Isolation Forest in 10 Lines")
    print("="*50)
    
    # Simpler feature extraction
    def simple_features(text):
        text = text.lower()
        return [
            len(text),
            sum(1 for word in ['urgent', 'immediate', 'emergency'] if word in text),
            sum(1 for word in ['payment', 'transfer', 'money'] if word in text)
        ]
    
    # Normal behavior patterns
    normal_data = [
        simple_features("Hi team, please review the report"),
        simple_features("Meeting at 2 PM tomorrow"),
        simple_features("Can you send me the document?")
    ]
    
    # Train model
    model = IsolationForest(contamination=0.3, random_state=42)
    model.fit(normal_data)
    
    # Test
    test_msg = "URGENT: Send money now to account 1234!"
    test_features = simple_features(test_msg)
    prediction = model.predict([test_features])
    
    print(f"Test message: '{test_msg}'")
    print(f"Features: {test_features}")
    print(f"Prediction: {'ANOMALY' if prediction[0] == -1 else 'NORMAL'}")
    print(f"→ Isolation Forest flags unusual feature combinations")

if __name__ == "__main__":
    run_social_engineering_demo()
    quick_isoforest_demo()
    
    # Practical takeaways
    print("\n🛡️  Practical Defense Applications:")
    print("• Email security filters")
    print("• Chat message monitoring") 
    print("• Financial request validation")
    print("• Can run in real-time on employee communications")
# Out:
# 🔍 Social Engineering Anomaly Detection Demo
# ...
# 🏢 Training on normal employee behavior...
# ✅ Model trained on 10 normal messages
#
# 📋 Testing Message Anomaly Detection:
# ---------------------------------------------
# 1. ✅ NORMAL
#    Message: Hi team, can you please review the Q3 report?...
#    Anomaly score: 0.002
#    Features: [len:45, urgency:0, money:0]
#
# 2. ✅ NORMAL
#    Message: Meeting scheduled for 2 PM in conference room B...
#    Anomaly score: 0.247
#    Features: [len:47, urgency:0, money:0]
#
# 3. ✅ NORMAL
#    Message: Could you send me the project timeline when you ha...
#    Anomaly score: 0.009
#    Features: [len:62, urgency:0, money:0]
#
# 4. ✅ NORMAL
#    Message: URGENT: Wire $50,000 to account 1234 immediately!...
#    Anomaly score: 0.204
#    Features: [len:49, urgency:2, money:0]
#
# 5. ✅ NORMAL
#    Message: CEO DIRECTIVE: Verify your login credentials NOW...
#    Anomaly score: 0.222
#    Features: [len:48, urgency:0, money:0]
#
# 6. ✅ NORMAL
# ...
